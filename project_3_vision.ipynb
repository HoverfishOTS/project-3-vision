# %% [markdown]
# # Track 3: Computer Vision (Images)
#
# **Program Context:** Multimodal Emotion Recognition Summer Research Program
#
# **Colab Instructions:** To run this notebook in Google Colab, click the badge in the README or upload the file to your Google Drive, right-click, and select 'Open with Google Colaboratory'.
#
# Fill in every cell marked `TODO`. Run cells top to bottom.

# %% [markdown]
# ## 0. Install and import

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ## 1. Week 2 -- Load FER-2013 Dataset
#
# Load the image dataset into memory. The FER-2013 dataset is typically structured in folders named after the emotion categories.

# %%
# TODO: read images and labels from the dataset directory.

# %% [markdown]
# ## 2. Week 4 -- Preprocess Images
#
# Standardize the images for the neural network. This includes ensuring all images are the same size, converting to grayscale (if not already), and normalizing pixel values to a range between 0 and 1.

# %%
# TODO: implement image resizing and pixel normalization.

# %% [markdown]
# ## 3. Week 6 -- Define CNN Architecture
#
# Split the data into training and testing sets. Then, design a Convolutional Neural Network (CNN) architecture to extract spatial features from the facial images.

# %%
# TODO: define a sequential Keras model with Conv2D, MaxPooling2D, and Dense layers.

# %% [markdown]
# ## 4. Week 6 -- Train Model
#
# Train the CNN on your preprocessed training data. Monitor the training and validation accuracy to ensure the model is learning without overfitting.

# %%
# TODO: split data, compile, and fit the model.

# %% [markdown]
# ## 5. Week 7 -- Evaluation
#
# Evaluate the model's performance on the unseen test set. Visualize the results using a confusion matrix to identify which emotional expressions are most frequently confused.

# %%
# TODO: evaluate on test set, generate predictions, and visualize confusion matrix.

# %% [markdown]
# ## 6. Week 9 -- Synthesis and Ethics
#
# Analyze your model's performance across the different emotion classes. Which facial expressions are most easily confused? Draft a discussion on demographic bias in computer vision datasets and the ethical considerations of deploying visual emotion recognition AI in public spaces.

# %% [markdown]
# *TODO: Write your week 9 analysis here.*

# %% [markdown]
# ## 7. Week 10 -- Final Deliverables
#
# Prepare your final research paper or poster and your presentation. Document your CNN layer architecture, training history (loss/accuracy curves), and final evaluation metrics.
